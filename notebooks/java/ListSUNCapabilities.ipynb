# %%
// Java crypto algorithms for provider SUN
java.security.Provider provider = java.security.Security.getProvider("SUN");
java.util.Iterator  it = provider.keySet().iterator();        
while (it.hasNext())
{
    String entry = (String)it.next();                        
    if (entry.startsWith("Alg.Alias.")) {
        entry = entry.substring("Alg.Alias.".length());
    }            
    String  factoryClass = entry.substring(0, entry.indexOf('.'));
    String  name = entry.substring(factoryClass.length() + 1);
    System.out.println(factoryClass + ": " + name);
}
# Out:
# Signature: SHA1/DSA
# Signature: 1.2.840.10040.4.3
# Signature: DSS
# SecureRandom: SHA1PRNG ImplementedIn
# KeyStore: JKS
# MessageDigest: SHA-1
# MessageDigest: SHA
# KeyStore: CaseExactJKS
# CertStore: com.sun.security.IndexedCollection ImplementedIn
# Signature: SHA256withDSA
# MessageDigest: OID.1.3.14.3.2.26
# Signature: DSA
# KeyFactory: DSA ImplementedIn
# KeyStore: JKS ImplementedIn
# AlgorithmParameters: DSA ImplementedIn
# Signature: NONEwithDSA
# CertificateFactory: X509
# Signature: SHA256withDSA SupportedKeyClasses
# CertStore: com.sun.security.IndexedCollection
# Provider: id className
# MessageDigest: 1.3.14.3.2.26
# Signature: SHA-1/DSA
# KeyStore: DKS
# CertificateFactory: X.509 ImplementedIn
# Signature: OID.2.16.840.1.101.3.4.3.2
# Signature: OID.2.16.840.1.101.3.4.3.1
# Signature: SHA1withDSA KeySize
# Signature: NONEwithDSA KeySize
# CertPathValidator: PKIX ImplementedIn
# KeyFactory: DSA
# Configuration: JavaLoginConfig
# Signature: OID.1.2.840.10040.4.3
# MessageDigest: OID.2.16.840.1.101.3.4.2.4
# KeyFactory: 1.2.840.10040.4.1
# MessageDigest: MD5 ImplementedIn
# MessageDigest: OID.2.16.840.1.101.3.4.2.3
# MessageDigest: OID.2.16.840.1.101.3.4.2.2
# MessageDigest: OID.2.16.840.1.101.3.4.2.1
# Signature: RawDSA
# Provider: id name
# AlgorithmParameters: 1.2.840.10040.4.1
# CertPathBuilder: PKIX ValidationAlgorithm
# Policy: JavaPolicy
# Signature: SHA224withDSA KeySize
# AlgorithmParameters: OID.1.2.840.10040.4.1
# AlgorithmParameters: 1.3.14.3.2.12
# Signature: SHA/DSA
# KeyPairGenerator: 1.3.14.3.2.12
# MessageDigest: SHA-384
# MessageDigest: SHA-224
# Signature: SHA1withDSA ImplementedIn
# AlgorithmParameterGenerator: DSA
# Signature: NONEwithDSA SupportedKeyClasses
# SecureRandom: NativePRNGBlocking
# MessageDigest: SHA-512
# KeyFactory: OID.1.2.840.10040.4.1
# CertPathBuilder: PKIX
# Signature: 1.3.14.3.2.27
# MessageDigest: 2.16.840.1.101.3.4.2.4
# CertPathBuilder: PKIX ImplementedIn
# MessageDigest: 2.16.840.1.101.3.4.2.3
# Provider: id version
# MessageDigest: 2.16.840.1.101.3.4.2.2
# Signature: SHA256withDSA KeySize
# MessageDigest: 2.16.840.1.101.3.4.2.1
# AlgorithmParameters: DSA
# Signature: SHA1withDSA SupportedKeyClasses
# CertStore: Collection
# AlgorithmParameterGenerator: DSA ImplementedIn
# SecureRandom: NativePRNGNonBlocking
# KeyPairGenerator: DSA KeySize
# CertStore: LDAP
# CertificateFactory: X.509
# Signature: 2.16.840.1.101.3.4.3.2
# Signature: 2.16.840.1.101.3.4.3.1
# SecureRandom: NativePRNG
# CertStore: LDAP LDAPSchema
# CertStore: LDAP ImplementedIn
# KeyPairGenerator: DSA ImplementedIn
# CertPathValidator: PKIX ValidationAlgorithm
# CertStore: Collection ImplementedIn
# Signature: SHA224withDSA
# Signature: 1.3.14.3.2.13
# CertPathValidator: PKIX
# MessageDigest: SHA1
# AlgorithmParameterGenerator: DSA KeySize
# SecureRandom: SHA1PRNG
# Signature: SHA1withDSA
# KeyFactory: 1.3.14.3.2.12
# MessageDigest: SHA ImplementedIn
# KeyPairGenerator: DSA
# Provider: id info
# KeyPairGenerator: 1.2.840.10040.4.1
# Signature: SHAwithDSA
# MessageDigest: MD5
# Signature: DSAWithSHA1
# MessageDigest: SHA-256
# KeyPairGenerator: OID.1.2.840.10040.4.1
# Signature: SHA224withDSA SupportedKeyClasses
# MessageDigest: MD2
# No Outputs
